# %%
'''
整理：早起python

仅限用于学习研究，请勿用于任何商业用途
'''
# Out:
# '\n整理：早起python\n\n仅限用于学习研究，请勿用于任何商业用途\n'

# %%
#########全球疫情地图

# %%
import pandas as pd
world = pd.read_csv('全球疫情数据0401.csv')

# %%
name1 = [
    
    'Burundi',
    'Sierra Leone',
    'Botswana',
'Northern Mariana',
'Bermuda',
'British Virgin Islands',
'Anguilla',
'Grenada',
'Saint Kitts and Nevis',
'Turks and Caicos Islands',
'Guinea Bissau',
'Mali',
'Libya',
'Laos',
'Belize',
'Burma',
'Dominica',
'Mozambique',
'Syria',
'Isle of man',
'Papua New Guinea',
'Eritrea',
'Uganda',
'Angola',

'East Timor',

'New Caledonia',

'Madagascar',

'Zimbabwe',

'Cape Verde',

'Montserrat',

'Haiti',

'Niger',

'Chad',

'El Salvador',

'Nicaragua',

'Fiji',

'Mauritius',

'Zambia',

'Guernsey',

'Djibouti',

'Kyrgyzstan',

'Barbados',

'Montenegro',

'Gambia',

'United States Virgin Islands',

'Guam',

'Greenland',

'Benin',

'Somalia',

'Tanzania',

'Liberia',

'Cooperative Republic of Guyana',

'horse',

'Bahamas',

'Uzbekistan',

'Guadeloupe',

'Cayman Islands',

'Congo (Brazzaville)',

'Central African Republic',

'Seychelles',

'Equatorial Guinea',

'Namibia',

'Rwanda',

'Swaziland',

'Mauritania',

'Aruba',

'Diamond Princess',

'Suriname',

'Curacao',

'Saint Lucia',

'Saint Vincent and the Grenadines',

'Jersey',

'Antigua and Barbuda',

'Puerto Rico',

'Guatemala',

'Uruguay',

'Venezuela',

'Sultan',

'Guinea',

'Ethiopia',

'Kazakhstan',

'Kenya',

'Trinidad and Tobago',

'Gabon',

'Garner',

'French Polynesia',

'Cuba',

'Reunion Island',

'Ivory Coast',

'Honduras',

'Bolivia',

'Saint Martin Island',

'St. Bartletts Island',

'Jamaica',

'Turkey',

'Congo (DRC)',

'Panama',

'Mongolia country',

'Burkina Faso',

'Cyprus',

'Brunei',

'Martinique',

'French Guiana',

'Faroe Islands',

'Albania',

'Bangladesh',

'Bulgaria',

'Moldova',

'Maldives',

'Paraguay',

'Malta',

'Costa Rica',

'Colombia',

'Togo',

'Peru',

'Slovakia',

'Cameroon',

'The Vatican',

'Serbia',

'Gibraltar',

'Bhutan',

'Liechtenstein',

'Palestine',

'South Africa',

'Bosnia and Herzegovina',

'Hungary',

'Slovenia',

'Poland',

'Argentina',

'Chile',

'Ukraine',

'Saudi Arabia',

'Tunisia',

'Senegal',

'Latvia',

'Morocco',

'Jordan',

'Portugal',

'Andorra',

'Indonesia',

'Czech',

'Dominica',

'Armenia',

'Irish',

'Luxemburg',

'Ecuador',

'Qatar',

'San Marino',

'Monaco',

'Iceland',

'Mexico',

'Azerbaijan',

'Belarus',

'New Zealand',

'Lithuania',

'Nigeria',

'Egypt',

'Holland',

'Estonia',

'Danish',

'Romania',

'North Macedonia',

'Norway',

'Georgia',

'Pakistan',

'Greece',

'Algeria',

'Switzerland',

'Croatia',

'Austria',

'Oman',

'Afghanistan',

'Bahrain',

'Kuwait',

'Iraq',

'Lebanon',

'Israel',

'Iran',

'Brazil',

'Belgian',

'Spain',

'Sweden',

'Russia',

'Britain',

'Italy',

'India',

'Philippines',

'Finland',

'The United Arab Emirates',

'Sri Lanka',

'Kampuchea',

'Nepal',

'Canada',

'Germany',

'Vietnam',

'France',

'United States',

'Korea',

'Australia',

'Malaysia',

'Japan',

'Singapore',

'Thailand' ,
'China']
data = world['confirmed'].to_list()

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker

c = (
    Map()
    .add("全球疫情", [list(z) for z in zip(name1, data)], "world",is_map_symbol_show=False,)
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        legend_opts=opts.LegendOpts(is_show=False),
        title_opts=opts.TitleOpts(title="全球疫情地图0401"),
        visualmap_opts=opts.VisualMapOpts(max_=10000),
    )
    .render_notebook()
)
c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="4b1985655f204a6e896a4d9139583221" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_4b1985655f204a6e896a4d9139583221 = echarts.init(
#                     document.getElementById('4b1985655f204a6e896a4d9139583221'), 'white', {renderer: 'canvas'});
#                 var option_4b1985655f204a6e896a4d9139583221 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
########################################

# %%
df = pd.read_csv('全球疫情历史数据.csv')
df = df[['date','country','confirmed']]

# %%
UK = df[df['country'] == '英国']['confirmed'].to_list()[-20:]
Italy = df[df['country'] == '意大利']['confirmed'].to_list()[-20:]
US = df[df['country'] == '美国']['confirmed'].to_list()[-20:]
Spain = df[df['country'] == '西班牙']['confirmed'].to_list()[-20:]
Germany = df[df['country'] == '德国']['confirmed'].to_list()[-20:]
Iran = df[df['country'] == '伊朗']['confirmed'].to_list()[-20:]
Korea = df[df['country'] == '韩国']['confirmed'].to_list()[-20:]
France = df[df['country'] == '法国']['confirmed'].to_list()[-20:]
Switzerland = df[df['country'] == '瑞士']['confirmed'].to_list()[-20:]

# %%
date = df[df['country'] == '英国']['date'].to_list()[-20:]
for i in range(len(date)):
    date[i] = date[i][6:]

# %%
c={"英国":UK,
   '美国':US,
  '意大利':Italy ,
  '西班牙':Spain ,
  '德国':Germany ,
   '伊朗':Iran ,
  '韩国':Korea ,
  '法国':France ,
  '瑞士':Switzerland ,}  
df1=pd.DataFrame(c)

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar, Timeline
from pyecharts.commons.utils import JsCode
from pyecharts.faker import Faker
from pyecharts.globals import ThemeType

def get_value(df1,k):
    data = df1.loc[k].to_list()
    k = k + 1
    
    return data,k 

df1 = df1 

x = df1.columns.to_list()
tl = Timeline()
tl.add_schema(is_auto_play = False,
play_interval = 500,
is_loop_play = False)
k = 0
for i in date:
    data = get_value(df1,k)[0]
    
    X = df1.columns.to_list()
    
    Y =  get_value(df1,k)[0]
    
    s = {"国家" :X,
        "数量":Y}
    tem=pd.DataFrame(s)
    tem = tem.sort_values(by="数量",ascending= True) 
    X = tem['国家'].to_list()
    Y = tem['数量'].to_list()
    
    k = get_value(df1,k)[1]
    
    bar = (
        Bar(init_opts=opts.InitOpts(theme=ThemeType.WALDEN))
        .add_xaxis(X)
        .add_yaxis("确诊人数", Y)
        .reversal_axis()
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            legend_opts=opts.LegendOpts(is_show=False),
            title_opts=opts.TitleOpts("".format(i)),
            graphic_opts=[
                opts.GraphicGroup(
                    graphic_item=opts.GraphicItem(
                        rotation=JsCode("Math.PI / 4"),
                        bounding="raw",
                        right=100,
                        bottom=110,
                        z=100,
                    ),
                    children=[
                        opts.GraphicRect(
                            graphic_item=opts.GraphicItem(
                                left="center", top="center", z=100
                            ),
                            graphic_shape_opts=opts.GraphicShapeOpts(
                                width=400, height=50
                            ),
                            graphic_basicstyle_opts=opts.GraphicBasicStyleOpts(
                                fill="rgba(0,0,0,0.3)"
                            ),
                        ),
                        opts.GraphicText(
                            graphic_item=opts.GraphicItem(
                                left="center", top="center", z=100
                            ),
                            graphic_textstyle_opts=opts.GraphicTextStyleOpts(
                                text="重点国家{}日数据".format(i),
                                font="bold 26px Microsoft YaHei",
                                graphic_basicstyle_opts=opts.GraphicBasicStyleOpts(
                                    fill="#fff"
                                ),
                            ),
                        ),
                    ],
                )
            ],
        )
    )
    tl.add(bar, "".format(i))
tl.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4a7847b644194345b5d048783bf8e9ff" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4a7847b644194345b5d048783bf8e9ff = echarts.init(
#                     document.getElementById('4a7847b644194345b5d048783bf8e9ff'), 'white', {renderer: 'canvas'});
#                 var option_4a7847b644194345b5d048783bf8e9ff = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "bar",
#                 "name": "\u786e\u8bca\u4eba\u6570",
#                 "data": [
#                     9887,
#                     16605,
#                     25481,
#                     47593,
#                     52836,
#                     71985,
#                     102136,
#                     106128,
# ...

# %%
##########

# %%
CN = pd.read_csv('中国历史数据_截至4.13日9点30.csv')

# %%
CN = CN.set_index('日期')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-4ee2d8c1b9c1> in <module>
# ----> 1 CN = CN.set_index('日期')
#
# /Users/anaconda/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4409
#    4410         if missing:
# -> 4411             raise KeyError("None of {} are in the columns".format(missing))
#    4412
#    4413         if inplace:
#
# KeyError: "None of ['日期'] are in the columns"

# %%
import matplotlib.pyplot as plt 
plt.style.use('seaborn-darkgrid') # 设置画图的风格
plt.rc('font', family='simhei', size=6) #设置图中字体和大小
plt.rc('figure', figsize=(4,3), dpi=150) # 设置图的大小
CN.plot()
# Out:
# /Users/anaconda/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 26085 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/anaconda/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 26399 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/anaconda/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 26085 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/anaconda/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 26399 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import pyecharts.options as opts
import pandas as pd
from pyecharts.charts import Line
from pyecharts.faker import Faker
CN = pd.read_csv('中国历史数据_截至4.13日9点30.csv')
c = (
    Line()
    .add_xaxis(CN['日期'].to_list())
    .add_yaxis("确诊", CN['confirm'].to_list(),label_opts=opts.LabelOpts(is_show=False),symbol="x")
    .add_yaxis("死亡", CN['dead'].to_list(),label_opts=opts.LabelOpts(is_show=False),symbol= 'o')
    .add_yaxis("重症", CN['severe'].to_list(),label_opts=opts.LabelOpts(is_show=False),symbol= 'rect')
    .add_yaxis("疑似", CN['suspect'].to_list(),label_opts=opts.LabelOpts(is_show=False),symbol="triangle")
    .add_yaxis("治愈", CN['heal'].to_list(),label_opts=opts.LabelOpts(is_show=False),symbol="diamond")
    .set_global_opts(title_opts=opts.TitleOpts(title=""))
    .render_notebook()
)
c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="84ccae0652504989976e30ca89146f19" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_84ccae0652504989976e30ca89146f19 = echarts.init(
#                     document.getElementById('84ccae0652504989976e30ca89146f19'), 'white', {renderer: 'canvas'});
#                 var option_84ccae0652504989976e30ca89146f19 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...
